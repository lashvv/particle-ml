# %%
import pandas as pd

# %%
df = pd.read_parquet('../data/raw/data.parquet')

# %%
df.head()
# Out:
#    truth_HT_tracks  truth_HT_tracks_2GeV  truth_HT_tracks_5GeV  \
# 0       395.015503            379.750519            339.016571
# 1       298.974335            276.244202            252.651077
# 2       579.767883            556.855652            491.024078
# 3       313.115967            279.098602            241.805145
# 4       588.024658            551.901855            522.104065
#
#    truth_HT_tracks_10GeV  truth_pT_track1  truth_pT_track2  \
# 0             291.702271        43.137352        39.472950
# 1             241.618103       124.107307       107.218437
# 2             466.301941       201.965652        44.236809
# 3             209.315384       119.625839        54.612926
# 4             494.843262        94.890800        80.814285
#
#    truth_pT_track3p_r1  truth_pT_track_r1  truth_pT_track_r2  \
# 0            23.505688          17.155613           1.035230
# 1             2.099513           1.065130           3.783245
# ...

# %%
df.describe()
# Out:
#        truth_HT_tracks  truth_HT_tracks_2GeV  truth_HT_tracks_5GeV  \
# count     1.035835e+06          1.035835e+06          1.035835e+06
# mean      3.498906e+02          3.058959e+02          2.686213e+02
# std       2.435034e+02          2.395352e+02          2.323787e+02
# min       0.000000e+00          0.000000e+00          0.000000e+00
# 25%       2.019877e+02          1.611692e+02          1.289116e+02
# 50%       2.859917e+02          2.404851e+02          2.044825e+02
# 75%       4.211189e+02          3.728638e+02          3.305929e+02
# max       5.356273e+03          5.305486e+03          5.270161e+03
#
#        truth_HT_tracks_10GeV  truth_pT_track1  truth_pT_track2  \
# count           1.035835e+06     1.035835e+06     1.035835e+06
# mean            2.334444e+02     8.261674e+01     4.382557e+01
# std             2.228864e+02     7.622245e+01     3.860418e+01
# min             0.000000e+00    -9.900000e+01    -9.900000e+01
# ...
